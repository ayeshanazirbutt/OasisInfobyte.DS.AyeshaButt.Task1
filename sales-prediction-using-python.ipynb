# %% [markdown]
# <center><h1>TASK 2</h1></center>
# <center><h1>SALES PREDICTION USING PYTHON</h1></center>
# <center><h2 style="color: lavender ;background-color:blue;" > OASIS INFOBYTE<br>
#  Data Science<br> By : Ayesha Nazir Butt </h2></center>

# %% [markdown]
# **Sales Prediction with Python: Optimizing Business Strategies for Maximum Revenue**
#
# <center><h5 style="color: white ;background-color:black;" > In today's dynamic market landscape, Sales Prediction using Python emerges as a crucial tool for businesses aiming to thrive. This project revolves around harnessing the power of machine learning to forecast future sales. By scrutinizing factors like advertising expenditures, customer segmentation, and marketing platforms, companies gain the ability to make strategic decisions that resonate with their audience.
#
# Through the lens of historical data analysis, predictive models are constructed, serving as guiding beacons for businesses in a data-driven world. The marriage of machine learning and sales prediction empowers organizations to fine-tune their marketing strategies, allocate resources with precision, and tap into untapped revenue potential.
#
# However, the journey doesn't end with model creation. By consistently enriching the models with fresh data, businesses can adapt swiftly to the evolving market dynamics. This adaptability ensures that the predictive prowess remains refined, allowing companies to make informed choices in the face of a competitive landscape.
#
# In a nutshell, Sales Prediction with Python isn't just a project; it's a pathway to strategic excellence. It equips businesses with the tools to not only forecast sales but also orchestrate their future growth with unwavering confidence. By leveraging machine learning, historical insights, and real-time data, this project empowers companies to navigate the complexities of modern commerce and emerge as industry leaders.
# </h5></center>

# %% [markdown]
# **1) IMPORTING THE LIBRARIES**

# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
os.getcwd()
# Out:
# '/Users/ayeshabutt/Downloads/OASIS INFOBYTY DS AYESHA/Oasis.Info.DS.AyeshaB.Task2'

# %% [markdown]
# **2) LOADING THE DATASET:**

# %%
# Load dataset
df = pd.read_csv("/Users/ayeshabutt/Downloads/OASIS INFOBYTY DS AYESHA/Oasis.Info.DS.AyeshaB.Task2/Advertising.csv")

# %% [markdown]
# **3) EXPLORATORY DATA ANALYSIS:**

# %%
# View the first few rows of the dataset

df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Get the column names of the dataset

df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# To rename the column 'Unnamed: 0' to 'Index'
df.rename(columns={'Unnamed: 0': 'Index'}, inplace=True)

# %%
df
# Out:
#      Index     TV  Radio  Newspaper  Sales
# 0        1  230.1   37.8       69.2   22.1
# 1        2   44.5   39.3       45.1   10.4
# 2        3   17.2   45.9       69.3    9.3
# 3        4  151.5   41.3       58.5   18.5
# 4        5  180.8   10.8       58.4   12.9
# ..     ...    ...    ...        ...    ...
# 195    196   38.2    3.7       13.8    7.6
# 196    197   94.2    4.9        8.1    9.7
# 197    198  177.0    9.3        6.4   12.8
# 198    199  283.6   42.0       66.2   25.5
# 199    200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Get the shape of the dataset (rows, columns)

df.shape
# Out:
# (200, 5)

# %%
# Check information about the dataset, data types, and missing values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Index      200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# Get statistical summary of the numerical columns
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# Index      200.0  100.5000  57.879185  1.0  50.750  100.50  150.250  200.0
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
# Check for missing values in the dataset
df.isnull().values.any()
df.isnull().sum()
# Out:
# Index        0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# **4) Data Visualization:**

# %%
# Scatter plots to check the linearity assumption between each independent variable (TV, Radio, Newspaper) and the dependent variable (Sales)

sns.pairplot(df, x_vars=["TV", "Radio", "Newspaper"], y_vars="Sales", kind="reg")
# Out:
# /Users/ayeshabutt/micromamba/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Histograms to check the normality assumption of the dependent variable (Sales)

df.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'Index'}>,
#         <Axes: title={'center': 'TV'}>],
#        [<Axes: title={'center': 'Radio'}>,
#         <Axes: title={'center': 'Newspaper'}>],
#        [<Axes: title={'center': 'Sales'}>, <Axes: >]], dtype=object)

# %%
# Linear regression plots to visualize the relationship between each independent variable and the dependent variable

sns.lmplot(x='TV', y='Sales', data=df)
sns.lmplot(x='Radio', y='Sales', data=df)
sns.lmplot(x='Newspaper',y= 'Sales', data=df)
# Out:
# /Users/ayeshabutt/micromamba/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/ayeshabutt/micromamba/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/ayeshabutt/micromamba/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corrmat = df.corr()
# Set up the figure and axis for the heatmap
plt.figure(figsize=(12, 9))
sns.set(font_scale=1.2)  # Adjust font size for better readability

# Create a heatmap using Seaborn
sns.heatmap(corrmat, annot=True, cmap="YlGnBu", fmt=".2f", vmin=-1, vmax=1, center=0)

# Add title and adjust layout
plt.title("Correlation Heatmap")
plt.tight_layout()

# Display the heatmap
plt.show()

# %% [markdown]
# **5) MODEL PREPARATION:**

# %%
# Model Preparation
X = df.drop('Sales', axis=1)
y = df[["Sales"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=46)

# %% [markdown]
# **6) LINEAR REGRESSION MODEL:**

# %%
lin_model = sm.ols(formula="Sales ~ TV + Radio + Newspaper", data=df).fit()

# %%
# Print the coefficients and summary of the linear model
print("Coefficients:\n", lin_model.params, "\n")
print("Summary:\n", lin_model.summary(), "\n")
# Out:
# Coefficients:
#  Intercept    2.938889
# TV           0.045765
# Radio        0.188530
# Newspaper   -0.001037
# dtype: float64
#
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sun, 27 Aug 2023   Prob (F-statistic):           1.58e-96
# Time:                        22:16:14   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# **7) EVALUATE THE MODEL:**

# %%
results = []
names = []
models = [('LinearRegression', LinearRegression())]

for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    result = np.sqrt(mean_squared_error(y_test, y_pred))
    results.append(result)
    names.append(name)
    msg = f"{name}: {result:.4f}"
    print(msg)
# Out:
# LinearRegression: 1.7036

# %% [markdown]
# **8) MAKE REDICTIONS ON NEW DATA:**

# %%
# Make predictions on new data
new_data = pd.DataFrame({'TV': [100], 'Radio': [50], 'Newspaper': [25]})
predicted_sales = lin_model.predict(new_data)
print("Predicted Sales for new data:", predicted_sales)
# Out:
# Predicted Sales for new data: 0    16.915917
# dtype: float64

# %%
new_data = pd.DataFrame({'TV': [25], 'Radio': [63], 'Newspaper': [80]})
predicted_sales = lin_model.predict(new_data)
print("Predicted Sales for new data:", predicted_sales)
# Out:
# Predicted Sales for new data: 0    15.877397
# dtype: float64

# %% [markdown]
# ## Project Outcome
#
# - Machine learning empowers businesses to make informed decisions about marketing strategies and resource allocation.
# - The linear regression model reveals the impact of advertising expenses on sales across different platforms.
# - Model evaluation metrics like RMSE quantify predictive accuracy and help optimize performance.
# - Predicting sales on new data scenarios enables revenue forecasting based on various advertising strategies.
#
# ## Benefits
#
# - Sales prediction enhances marketing campaigns, budget allocation, and revenue forecasting.
# - Data-driven decisions improve resource utilization, reduce risks, and maximize profitability.
# - Updating the model with new data ensures adaptability to market changes and trends.
#
# ## Conclusion
#
# <center><h4 style="color:purple ;background-color:white;"> This project demonstrates the application of machine learning techniques in sales prediction using Python. Analyzing historical data and building predictive models empower businesses to make data-driven decisions, optimize marketing strategies, allocate resources effectively, and achieve better performance in a competitive market. Sales prediction is a powerful tool for businesses seeking to maximize revenue potential and stay competitive in their industry.</h4></center>
